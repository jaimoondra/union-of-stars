# %% [markdown]
# # Reduction in operations for union-of-stars using sparsification and decomposition
#
# Corresponds to Table 2 in the paper
#
# This notebook plots the reduction in the number of HIsing pulses, total number of operations (HIsing pulses and bit flips), and total time of HIsing pulses using sparse union-of-stars (i.e., using sparsification and decomposition techniques) as compared to classical union-of-stars algorithm for certain graphs in the MQLib library.
#
# The data for the plots is stored in folder `data/MQLib_experiment_results` and was generated using the script `mqlib-instances.ipynb` in the `notebooks` folder.

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# # Load the data

# %%
files = os.listdir('../data/MQLib_experiment_results/')
files = [f for f in files if f.endswith('.csv')]

df = pd.read_csv('../data/MQLib_experiment_results/' + files[0])
original_pulses = df[df['type'] == 'Original']['number_of_pulses'].values[0]
original_length = df[df['type'] == 'Original']['length_of_pulses'].values[0]
original_operations = (
        df[df['type'] == 'Original']['number_of_pulses'].values[0] +
        df[df['type'] == 'Original']['number_of_bit_flips'].values[0]
)
df['Frac pulses'] = df['number_of_pulses'] / original_pulses
df['Frac length'] = df['length_of_pulses'] / original_length
df['Frac operations'] = (df['number_of_pulses'] + df['number_of_bit_flips'])/ original_operations

for t in range(1, len(files)):
    df_instance = pd.read_csv('../data/MQLib_experiment_results/' + files[t])
    original_pulses = df_instance[df_instance['type'] == 'Original']['number_of_pulses'].values[0]
    original_length = df_instance[df_instance['type'] == 'Original']['length_of_pulses'].values[0]
    original_operations = (
            df_instance[df_instance['type'] == 'Original']['number_of_pulses'].values[0] +
            df_instance[df_instance['type'] == 'Original']['number_of_bit_flips'].values[0]
    )
    df_instance['Frac pulses'] = df_instance['number_of_pulses'] / original_pulses
    df_instance['Frac length'] = df_instance['length_of_pulses'] / original_length
    df_instance['Frac operations'] = (df_instance['number_of_pulses'] + df_instance['number_of_bit_flips'] )/ original_operations

    df = pd.concat([df, df_instance], ignore_index=True)


# Filter by number of vertices
df = df[(df['number_of_vertices'] >= 50) & (df['number_of_vertices'] < 200)]
# Filter by number of edges
df = df[(df['number_of_edges'] >= 2 * df['number_of_vertices']) & (df['number_of_edges'] < 2000)]

df = df[df['type'] != 'Original']
print(len(df['instance_name'].unique()))
# Out:
# 194

# %% [markdown]
# # Group by sparsification and decomposition parameters

# %%
df
# Out:
#       instance_name  number_of_vertices  number_of_edges                 type  \
# 77          g001649                 160              812               Sparse
# 78          g001649                 160              812  Sparse + Decomposed
# 79          g001649                 160              812  Sparse + Decomposed
# 80          g001649                 160              812  Sparse + Decomposed
# 81          g001649                 160              812  Sparse + Decomposed
# ...             ...                 ...              ...                  ...
# 15738       g001863                 160              812  Sparse + Decomposed
# 15739       g001863                 160              812  Sparse + Decomposed
# 15740       g001863                 160              812  Sparse + Decomposed
# 15741       g001863                 160              812  Sparse + Decomposed
# 15742       g001863                 160              812  Sparse + Decomposed
#
#        epsilon_decomposition decomposition_type  number_of_pulses  \
# 77                      0.00               none              2437
# 78                      0.10        exponential               421
# 79                      0.25        exponential               409
# 80                      0.50        exponential               388
# 81                      0.75        exponential               349
# ...                      ...                ...               ...
# 15738                   0.50             binary              4966
# 15739                   0.75             binary              5050
# 15740                   1.00             binary              4903
# 15741                   2.00             binary              4540
# 15742                   5.00             binary              4012
#
#        length_of_pulses  number_of_bit_flips  q_sparsification  \
# 77         88978.000000                 3248               0.2
# 78         84310.860740                  570               0.2
# 79         80468.945489                  568               0.2
# 80         70441.845199                  550               0.2
# 81         60216.147476                  528               0.2
# ...                 ...                  ...               ...
# 15738      52189.148548                12464               2.0
# 15739      54368.599621                12742               2.0
# 15740      54930.278287                12112               2.0
# 15741      54932.392532                11482               2.0
# 15742      54558.874140                10086               2.0
#
#        seed_sparsification  epsilon_sparsification  frac_edges_sparsification  \
# 77                     0.0                     NaN                        NaN
# 78                     0.0                     NaN                        NaN
# 79                     0.0                     NaN                        NaN
# 80                     0.0                     NaN                        NaN
# 81                     0.0                     NaN                        NaN
# ...                    ...                     ...                        ...
# 15738                  0.0                     NaN                        NaN
# 15739                  0.0                     NaN                        NaN
# 15740                  0.0                     NaN                        NaN
# 15741                  0.0                     NaN                        NaN
# 15742                  0.0                     NaN                        NaN
#
#        max_cut_approximation  Frac pulses  Frac length  Frac operations
# 77                  0.991744     1.000000     1.000000         1.000000
# 78                  0.771421     0.172753     0.947547         0.174318
# 79                  0.744889     0.167829     0.904369         0.171856
# 80                  0.810590     0.159212     0.791677         0.164996
# 81                  0.763630     0.143209     0.676753         0.154266
# ...                      ...          ...          ...              ...
# 15738               0.929393     2.037751     0.417727         3.065963
# 15739               0.944324     2.072220     0.435172         3.129639
# 15740               0.922751     2.011900     0.439667         2.992964
# 15741               0.929888     1.862946     0.439684         2.818294
# 15742               0.959685     1.646286     0.436695         2.479859
#
# [14550 rows x 17 columns]

# %%
df_exp = df[df['decomposition_type'] == 'exponential']

columns = ['q_sparsification', 'epsilon_decomposition', 'Frac pulses', 'Frac length', 'Frac operations', 'max_cut_approximation']

df_parameters = df_exp.groupby(['q_sparsification', 'epsilon_decomposition']).agg({
    'Frac pulses': 'mean',
    'Frac length': 'mean',
    'Frac operations': 'mean',
    'max_cut_approximation': 'mean'
}).reset_index()

df_parameters = df_parameters[df_parameters['max_cut_approximation'] > 0.90]

# %%
df_parameters # This is Table 2 in the paper
# Out:
#     q_sparsification  epsilon_decomposition  Frac pulses  Frac length  \
# 18               0.8                   1.00     0.352415     0.569292
# 21               1.0                   0.10     0.534672     0.870196
# 22               1.0                   0.25     0.487506     0.779692
# 23               1.0                   0.50     0.442998     0.680700
# 24               1.0                   0.75     0.418665     0.614083
# 25               1.0                   1.00     0.400020     0.566553
# 26               1.0                   2.00     0.350625     0.438990
# 27               1.0                   5.00     0.300766     0.298604
# 28               2.0                   0.10     0.733430     0.873219
# 29               2.0                   0.25     0.668303     0.773811
# 30               2.0                   0.50     0.604506     0.667692
# 31               2.0                   0.75     0.561279     0.594171
# 32               2.0                   1.00     0.530025     0.537471
# 33               2.0                   2.00     0.454067     0.405724
# 34               2.0                   5.00     0.363997     0.265536
#
#     Frac operations  max_cut_approximation
# 18         0.404287               0.900745
# 21         0.557148               0.914983
# 22         0.522866               0.917424
# 23         0.490973               0.913755
# 24         0.473762               0.916113
# 25         0.460231               0.915530
# 26         0.424993               0.912522
# 27         0.389230               0.912193
# 28         0.762057               0.948814
# 29         0.715505               0.949362
# 30         0.669794               0.947909
# 31         0.638390               0.946374
# 32         0.616375               0.945252
# 33         0.562373               0.946655
# 34         0.497603               0.943906
